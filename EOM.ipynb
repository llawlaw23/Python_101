# %%
# The computer thinks of a number, and you guess it.
# Concepts: loops, random numbers, input and conditions.

# %%
# Play against the computer.
# Concepts: random (choices), lists, conditions.
# choices = ["rock", "paper", "scissors"]
