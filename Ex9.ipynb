# %%
data = {
    "Name": ["Ava", "Ben", "Ava", "Liam", "Ben", "Ava"],
    "Subject": ["Math", "Science", "Math", "History", "Math", "Science"],
    "Score": [85, 78, 92, 88, 90, 75],
    "Date": ["2024-01-05", "2024-01-12", "2024-02-01", "2024-02-10", "2024-02-15", "2024-03-01"]
}

# %%
# 1. Filter rows where Score > 85

# %%
# 2. Filter rows where Subject is Math

# %%
# 3. filter rows where Name is Ava and Score < 85

# %%
# 4. Sort by Score (descending)

# %%
# 5. Sort by Subject then Score

# %%
# 6. Set Name as index

# %%
# 7. Select rows using .loc

# %%
# 8. Select by position using .iloc

# %%
# 9. Average score by Name

# %%
# 10. Score count per Subject

# %%
# 11. groupby Name and Subject to get average Score

# %%
# 12. Convert Score to float

# %%
# 13. Convert Subject to category

# %%
# 14. Convert Date column to datetime

# %%
# 15. Extract year/month/day from Date

# %% [markdown]
# Try your hands on this too

# %%
# Load this data into a DataFrame.

# Convert the date column to datetime format.



# Find:

# Highest score per subject

# Average score per month

# How many tests each student took

# The top 3 highest scores overall

# Sort by student name alphabetically, then by score.

# Filter all rows in February with a score above 85.
