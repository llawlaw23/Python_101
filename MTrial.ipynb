# %%
# Create a program that asks for a user’s favorite food and prints a message.

# Make a list of 3 movies and print them with a loop.

# %%
# Make a function that checks if a number is divisble by 3 and 5.

# Make a dictionary for 3 students and print each student’s name.

# %%
# Write a program that:

# Asks for 3 numbers

# Stores them in a list

# Prints the largest number
